# %%
import numpy as np
import pandas as pd

# next command ensures that plots appear inside the notebook
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns  # also improves the look of plots
sns.set()  # set Seaborn defaults
plt.rcParams['figure.figsize'] = [10, 5]  # default hor./vert. size of plots, in inches
plt.rcParams['lines.markeredgewidth'] = 1  # to fix issue with seaborn box plots; needed after import seaborn

# %%
df = pd.read_csv("../local_reset_100.csv")

# %%
filter_col = [col for col in df if col.startswith('timings.')]

# %%
df[filter_col]
# Out:
#     timings.total  timings.init  timings.circuitgen  timings.network  \
# 0        2661.749          0.07               0.067            1.719
# 1        2667.681          0.07               0.067            1.719
# 2        2690.169          0.07               0.067            1.719
# 3        2597.397          0.07               0.067            1.719
# 4        2682.618          0.07               0.067            1.719
# ..            ...           ...                 ...              ...
# 95       2453.776          0.07               0.067            1.719
# 96       2357.411          0.07               0.067            1.719
# 97       2302.235          0.07               0.067            1.719
# 98       2368.107          0.07               0.067            1.719
# 99       2185.669          0.07               0.067            1.719
#
#     timings.baseots  timings.setup  timings.otextension  timings.garbling  \
# ...

# %%
# plot the timings for each run
to_plot = ['timings.setup', 'timings.online']
df_plotting = df[to_plot].copy() / 1000 # for seconds
ax = df_plotting.plot()
ax.set_ylabel("Time (s)")
ax.set_xlabel("Run number")
ax.set_title("Duration of SFE, resetting the ABY party between each run")
ax.legend(['Setup', 'Online'])
