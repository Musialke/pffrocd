# %%
import numpy as np
import pandas as pd

# next command ensures that plots appear inside the notebook
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns  # also improves the look of plots
sns.set()  # set Seaborn defaults
plt.rcParams['figure.figsize'] = [15, 15]  # default hor./vert. size of plots, in inches
plt.rcParams['lines.markeredgewidth'] = 1  # to fix issue with seaborn box plots; needed after import seaborn

# %%
df_32 = pd.read_csv("/home/kamil/Documents/2023-09-03_22-30-25.csv")
df_64 = pd.read_csv("../dfs/2023-08-23_14-14-16.csv")
df_32_first_try = pd.read_csv("/home/kamil/Downloads/2023-09-03_15-21-22.csv")

# %%
df_64.describe()
# Out:
#        Unnamed: 0  cos_dist_np   cos_dist_sfe  total_time    sfe_time  \
# count  738.000000   738.000000   7.380000e+02  738.000000  738.000000
# mean    15.155827     0.736616  5.025463e+303   85.290098   83.356696
# std     18.432578     0.236768            inf    1.306976    1.311454
# min      0.000000     0.133294   1.332943e-01   82.099529   80.182911
# 25%      2.000000     0.520602   5.211794e-01   84.395090   82.463470
# 50%      7.000000     0.793276   7.952935e-01   85.146113   83.208207
# 75%     22.000000     0.938015   9.419256e-01   85.989310   84.063972
# max     75.000000     1.242318  3.708792e+306   90.902739   88.971017
#
#        extraction_time  ram_used  energy_used  online_time.bool.local_gates  \
# count       738.000000     738.0        738.0                    738.000000
# mean          1.933402       0.0          0.0                    407.933206
# std           0.112375       0.0          0.0                      8.280084
# ...

# %%
l = [df_32_first_try['timings.total'] / 1000, df_32['timings.total'] / 1000, df_64['timings.total'] / 1000]

# %%
# plt.xticks(rotation=0)
labels = ["32-bit\n1st try\nN=44", "32-bit\n2nd try\nN=321", "64-bit\nN=738"]
ax = plt.boxplot(l, labels=labels)
plt.title("SFE total execution time")
plt.ylabel("Time [s]")
plt.xlabel("Configuration")
# Out:
# Text(0.5, 0, 'Configuration')

# %%
df_32_timings = df_32['timings.total'] / 1000
df_32_timings.plot()
plt.title("SFE total time: 32-bit")
plt.ylabel("Time [s]")
plt.xlabel("Iteration #")
# Out:
# Text(0.5, 0, 'Iteration #')

# %%
df_32_timings_1st = df_32_first_try['timings.total'] / 1000
df_32_timings_1st.plot()
# Out:
# <Axes: >

# %%
df_64_timings = df_64['timings.total'] / 1000
df_64_timings.plot()
plt.title("SFE total time: 64-bit")
plt.ylabel("Time [s]")
plt.xlabel("Iteration #")
# Out:
# Text(0.5, 0, 'Iteration #')

# %%
df_32_timings[20]
# Out:
# 102.947202
